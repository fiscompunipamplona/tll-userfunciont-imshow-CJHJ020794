# %%
# Piramide de Pascal
n=20<
def pascal(n):
  for i in range(n):
    for k in range(0, i):
      a=1
      b=1
      num=i
      den=k*(i-k)
      while a<i:
        num=num*(i-a)
        a=a+1
      while b<k:
        den=den*((k-b)*(i-(k-b)))
      if den==0:
        den=1
      resp=num/den
      print(resp)
    print('\n')
  return

# %%
# 100 lanzamientos de moneda y 60 caras
n=100
def lanz(n):
  for i in range(n):
    a=1
    b=1
    num=i
    den=60*(i-60)
    while a<i:
      num=num*(i-a)
      a=a+1
    while b<60:
      den=den*((60-b)*(i-(60-b)))
    if den==0:
      den=1
  res=(num/den)/(2**n)
  return

# %%
# 100 lanzamientos y mas de 60 caras
def pascal(n):
  res=0
  for i in range(n):
    for k in range(60, i):
      a=1
      b=1
      num=i
      den=k*(i-k)
      while a<i:
        num=num*(i-a)
        a=a+1
      while b<k:
        den=den*((k-b)*(i-(k-b)))
      if den==0:
        den=1
    res=res+(num/den)
  res=res/(2**n)
  return
